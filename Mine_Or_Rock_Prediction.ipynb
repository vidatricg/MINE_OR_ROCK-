# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/sonardata.csv")
df
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
df.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#    0.0090  0.0032  R
# 0  0.0052  0.0044  R
# 1  0.0095  0.0078  R
# 2  0.0040  0.0117  R
# ...

# %%
df.tail()
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
#      0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 202  0.2684  ...  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065  0.0115
# 203  0.2154  ...  0.0061  0.0093  0.0135  0.0063  0.0063  0.0034  0.0032
# 204  0.2529  ...  0.0160  0.0029  0.0051  0.0062  0.0089  0.0140  0.0138
# 205  0.2354  ...  0.0086  0.0046  0.0126  0.0036  0.0035  0.0034  0.0079
# 206  0.2354  ...  0.0146  0.0129  0.0047  0.0039  0.0061  0.0040  0.0036
#
#      0.0090  0.0032  R
# 202  0.0193  0.0157  M
# ...

# %%
import numpy as np

# %%
df.shape
# Out:
# (207, 61)

# %%
df.describe()
# Out:
#            0.0200      0.0371      0.0428      0.0207      0.0954      0.0986  \
# count  207.000000  207.000000  207.000000  207.000000  207.000000  207.000000
# mean     0.029208    0.038443    0.043837    0.054053    0.075105    0.104599
# std      0.023038    0.033040    0.038521    0.046583    0.055669    0.059247
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013300    0.016400    0.018900    0.024450    0.037700    0.066950
# 50%      0.022800    0.030800    0.034200    0.044100    0.062000    0.092100
# 75%      0.035800    0.048100    0.058200    0.065700    0.101050    0.134150
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#            0.1539      0.1601      0.3109      0.2111  ...      0.0232  \
# count  207.000000  207.000000  207.000000  207.000000  ...  207.000000
# mean     0.121591    0.134677    0.177361    0.208245  ...    0.016034
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0.0200  207 non-null    float64
#  1   0.0371  207 non-null    float64
#  2   0.0428  207 non-null    float64
#  3   0.0207  207 non-null    float64
#  4   0.0954  207 non-null    float64
#  5   0.0986  207 non-null    float64
#  6   0.1539  207 non-null    float64
#  7   0.1601  207 non-null    float64
#  8   0.3109  207 non-null    float64
#  9   0.2111  207 non-null    float64
#  10  0.1609  207 non-null    float64
#  11  0.1582  207 non-null    float64
#  12  0.2238  207 non-null    float64
#  13  0.0645  207 non-null    float64
#  14  0.0660  207 non-null    float64
#  15  0.2273  207 non-null    float64
#  16  0.3100  207 non-null    float64
#  17  0.2999  207 non-null    float64
#  18  0.5078  207 non-null    float64
#  19  0.4797  207 non-null    float64
# ...

# %%
df.apply(pd.Series.value_counts)
# Out:
#         0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  \
# 0.0006     NaN     1.0     NaN     NaN     NaN     NaN     NaN     NaN
# 0.0015     1.0     NaN     1.0     NaN     NaN     NaN     NaN     NaN
# 0.0017     NaN     1.0     NaN     NaN     NaN     NaN     NaN     NaN
# 0.0019     NaN     1.0     NaN     NaN     NaN     NaN     NaN     NaN
# 0.0022     NaN     1.0     NaN     NaN     NaN     NaN     NaN     NaN
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 0.0148     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 0.0157     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 0.0332     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# M          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# R          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#         0.3109  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  \
# ...

# %%
df.groupby(df.columns[60]).mean()
# Out:
#      0.0200    0.0371    0.0428    0.0207    0.0954    0.0986    0.1539  \
# R
# M  0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
# R  0.022524  0.030232  0.035879  0.041664  0.061680  0.096199  0.113767
#
#      0.1601    0.3109    0.2111  ...    0.0232    0.0027    0.0065    0.0159  \
# R                                ...
# M  0.149832  0.213492  0.251022  ...  0.019352  0.016014  0.011643  0.012185
# R  0.117153  0.135584  0.158785  ...  0.012198  0.010533  0.009673  0.009451
#
#      0.0072    0.0167    0.0180    0.0084    0.0090    0.0032
# R
# M  0.009923  0.008914  0.007825  0.009060  0.008695  0.006930
# R  0.008581  0.007333  0.007708  0.006659  0.007058  0.006053
#
# [2 rows x 60 columns]

# %%
print("Asymmetry : ",0.5-(97/(111+97)))
# Out:
# Asymmetry :  0.033653846153846145

# %% [markdown]
# *Data* Info :
# - float64 & object(strings)
# - 5788 unique values
# - Mines=> 111 values
# - Rocks => 97 values
# - Asymmetry (M\\R) (deviation) => 0.0336 or 3.37% < 5.00%

# %%
df.head(2)
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
#
#    0.0090  0.0032  R
# 0  0.0052  0.0044  R
# 1  0.0095  0.0078  R
#
# [2 rows x 61 columns]

# %%
X = df.drop(df.columns[60], axis=1)
Y = df[df.columns[60]]

# %%
X.head(2)
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
#
#    0.2111  ...  0.0232  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  \
# 0  0.2872  ...  0.0125  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140
# 1  0.6194  ...  0.0033  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316
#
#    0.0084  0.0090  0.0032
# 0  0.0049  0.0052  0.0044
# 1  0.0164  0.0095  0.0078
#
# [2 rows x 60 columns]

# %%
Y.head(2)
# Out:
# 0    R
# 1    R
# Name: R, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.195, stratify=Y, random_state=42)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
ss = StandardScaler()

# %%
X1 = ss.fit_transform(X)

# %%
X1_train, X1_test, Y1_train, Y1_test = train_test_split(X1, Y, test_size = 0.32, stratify=Y, random_state=9876)

# %%
print(X1.shape, X1_train.shape, X1_test.shape)
# Out:
# (207, 60) (140, 60) (67, 60)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.195, stratify=Y, random_state=42)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (207, 60) (166, 60) (41, 60)

# %% [markdown]
# #### The Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print("Accuracy Score :", training_data_accuracy)
# Out:
# Accuracy Score : 0.8614457831325302

# %%
X_test_prediction = model.predict(X_test)
testing_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print("Accuracy Score :", testing_data_accuracy)
# Out:
# Accuracy Score : 0.7560975609756098

# %% [markdown]
#  Making Predictive system by giving input data

# %%
deploy_data = (0.0311,0.0491,0.0692,0.0831,0.0079,0.0200,0.0980,0.1016,0.2025,0.0767,0.1767,0.2555,0.2812,0.2722,0.3227,0.3463,0.5395,0.7911,0.9064,0.8701,0.7672,0.2957,0.4148,0.6043,0.3178,0.3482,0.6158,0.8049,0.6289,0.4999,0.5830,0.6660,0.4124,0.1260,0.2487,0.4676,0.5382,0.3150,0.2139,0.1848,0.1679,0.2328,0.1015,0.0713,0.0615,0.0779,0.0761,0.0845,0.0593,0.0066,0.0089,0.0087,0.0032,0.0130,0.0188,0.0101,0.0229,0.0182,0.0046,0.0038)

# %%
deploy_npdata = np.asarray(deploy_data)
deploy_reshape_data = deploy_npdata.reshape(1,-1)

# %%
prediction = model.predict(deploy_reshape_data)
if (prediction == "R"):
  print("Rock")
elif (prediction == "M"):
  print("Mine")
else:
  print("Neither")
# Out:
# Rock
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# K Nearest Neighbour

# %% [markdown]
# #### Correlation & Center check

# %%
X.corr()
# Out:
#           0.0200    0.0371    0.0428    0.0207    0.0954    0.0986    0.1539  \
# 0.0200  1.000000  0.736104  0.571706  0.490853  0.345744  0.238824  0.262095
# 0.0371  0.736104  1.000000  0.779915  0.607297  0.419877  0.332319  0.279328
# 0.0428  0.571706  0.779915  1.000000  0.782662  0.546365  0.346271  0.190628
# 0.0207  0.490853  0.607297  0.782662  1.000000  0.729338  0.352901  0.248713
# 0.0954  0.345744  0.419877  0.546365  0.729338  1.000000  0.597438  0.334831
# 0.0986  0.238824  0.332319  0.346271  0.352901  0.597438  1.000000  0.703624
# 0.1539  0.262095  0.279328  0.190628  0.248713  0.334831  0.703624  1.000000
# 0.1601  0.356312  0.334747  0.237974  0.248131  0.203590  0.471942  0.675612
# 0.3109  0.356822  0.317929  0.253615  0.252048  0.176522  0.329145  0.469490
# 0.2111  0.318440  0.270787  0.219641  0.238136  0.183240  0.288639  0.425675
# 0.1609  0.343362  0.297186  0.274751  0.270466  0.232939  0.333560  0.398590
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(24,24))
sns.heatmap(X.corr(), annot=True, fmt = '.2f')
plt.show()

# %%
X['cent'] = Y.map({'R':0,'M':1})

# %%
np.abs(X.corr()['cent']).sort_values().tail(3)
# Out:
# 0.1582    0.390331
# 0.1609    0.431452
# cent      1.000000
# Name: cent, dtype: float64

# %%
# initial points : 0.432855 & 0.392245

# %% [markdown]
# #### Train_Test_Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X2 = X.drop(['cent'], axis=1)
Y2 = Y

# %%
X2_train, X2_test, Y2_train, Y2_test = train_test_split(X2, Y2, test_size = 0.25, random_state=42)

# %%
ss = StandardScaler()

# %%
sX2_train = ss.fit_transform(X2_train)
sX2_test = ss.transform(X2_test)

# %% [markdown]
# #### KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
test_accuracy_table = []
for k in range (1,50):
  knn_model = KNeighborsClassifier(n_neighbors = k)
  knn_model.fit(sX2_train, Y2_train)
  y_prediction = knn_model.predict(sX2_test)
  test_accuracy = accuracy_score(Y2_test, y_prediction)
  test_accuracy_table.append(test_accuracy)

# %%
print(test_accuracy_table)
# Out:
# [0.8269230769230769, 0.8461538461538461, 0.7884615384615384, 0.8653846153846154, 0.7692307692307693, 0.7884615384615384, 0.75, 0.7307692307692307, 0.7115384615384616, 0.7115384615384616, 0.6538461538461539, 0.6730769230769231, 0.6730769230769231, 0.6923076923076923, 0.6923076923076923, 0.6923076923076923, 0.7307692307692307, 0.7115384615384616, 0.7307692307692307, 0.7307692307692307, 0.7115384615384616, 0.7115384615384616, 0.7307692307692307, 0.6923076923076923, 0.6923076923076923, 0.6730769230769231, 0.6538461538461539, 0.6538461538461539, 0.6923076923076923, 0.6730769230769231, 0.6923076923076923, 0.6730769230769231, 0.6923076923076923, 0.6730769230769231, 0.6538461538461539, 0.6730769230769231, 0.6538461538461539, 0.6538461538461539, 0.6346153846153846, 0.6153846153846154, 0.6346153846153846, 0.6538461538461539, 0.6346153846153846, 0.6346153846153846, 0.6153846153846154, 0.6153846153846154, 0.6153846153846154, 0.6153846153846154, 0.6153846153846154]

# %%
confusion_matrix(Y2_test, y_prediction)
# Out:
# array([[19, 12],
#        [ 8, 13]])

# %%
print(classification_report(Y2_test, y_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            M       0.70      0.61      0.66        31
#            R       0.52      0.62      0.57        21
#
#     accuracy                           0.62        52
#    macro avg       0.61      0.62      0.61        52
# weighted avg       0.63      0.62      0.62        52

# %%
plt.scatter(test_accuracy_table, range(1,50))
plt.xlabel("Accuracy")
plt.ylabel("kNN")
plt.show()

# %% [markdown]
# #### 2-NN

# %%
knn_model = KNeighborsClassifier(n_neighbors = 2)
knn_model.fit(sX2_train, Y2_train)
y_prediction = knn_model.predict(sX2_test)
test_accuracy1 = accuracy_score(Y2_test, y_prediction)
confusion1 = confusion_matrix(Y2_test, y_prediction)
report1 = classification_report(Y2_test, y_prediction)

# %%
test_accuracy1
# Out:
# 0.8461538461538461

# %%
confusion1
# Out:
# array([[28,  3],
#        [ 5, 16]])

# %%
print(report1)
# Out:
#               precision    recall  f1-score   support
#
#            M       0.85      0.90      0.88        31
#            R       0.84      0.76      0.80        21
#
#     accuracy                           0.85        52
#    macro avg       0.85      0.83      0.84        52
# weighted avg       0.85      0.85      0.84        52

# %% [markdown]
# #### 6-NN

# %%
knn_model = KNeighborsClassifier(n_neighbors = 6)
knn_model.fit(sX2_train, Y2_train)
y_prediction = knn_model.predict(sX2_test)
test_accuracy2 = accuracy_score(Y2_test, y_prediction)
confusion2 = confusion_matrix(Y2_test, y_prediction)
report2 = classification_report(Y2_test, y_prediction)

# %%
test_accuracy2
# Out:
# 0.7884615384615384

# %%
confusion2
# Out:
# array([[26,  5],
#        [ 6, 15]])

# %%
print(report2)
# Out:
#               precision    recall  f1-score   support
#
#            M       0.81      0.84      0.83        31
#            R       0.75      0.71      0.73        21
#
#     accuracy                           0.79        52
#    macro avg       0.78      0.78      0.78        52
# weighted avg       0.79      0.79      0.79        52

# %%
print(test_accuracy2) # The user probably meant to print this variable which was defined earlier
# Out:
# 0.7884615384615384

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# Define parameter grid
param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale', 'auto']  # Only relevant for 'rbf' kernel
}

# Initialize SVM classifier
svc = SVC()

# Initialize GridSearchCV
grid_search = GridSearchCV(svc, param_grid, cv=5, scoring='accuracy')

# Fit GridSearchCV
grid_search.fit(X_train, Y_train)

# Best parameters
print("Best parameters:", grid_search.best_params_)

# Best model
best_model = grid_search.best_estimator_

# Evaluate the best model
y_pred = best_model.predict(X_test)
print("Accuracy:", accuracy_score(Y_test, y_pred))
# Out:
# Best parameters: {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# Accuracy: 0.8048780487804879

# %%
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC # Make sure to import the SVC class

# Assuming 'best_model' from your GridSearchCV is the classifier you want to use
cv_scores = cross_val_score(best_model, X, Y, cv=5, scoring='accuracy')
print("Cross-Validation Accuracy Scores:", cv_scores)
print("Mean Accuracy:", cv_scores.mean())

# If you intended to use a different classifier, replace 'best_model' with the appropriate variable name
# Out:
# Cross-Validation Accuracy Scores: [1. 1. 1. 1. 1.]
# Mean Accuracy: 1.0

# %%
from sklearn.metrics import confusion_matrix
y_pred = best_model.predict(X_test) # Changed clf to best_model
conf_matrix = confusion_matrix(Y_test, y_pred)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Confusion Matrix:
#  [[20  2]
#  [ 6 13]]

# %%
from sklearn.metrics import classification_report
print("Classification Report:\n", classification_report(Y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            M       0.77      0.91      0.83        22
#            R       0.87      0.68      0.76        19
#
#     accuracy                           0.80        41
#    macro avg       0.82      0.80      0.80        41
# weighted avg       0.81      0.80      0.80        41

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# Create a pipeline with scaling and classification
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', RandomForestClassifier(n_estimators=100, random_state=42))
])

# Fit the model
pipeline.fit(X_train, Y_train)

# Make predictions and evaluate
y_pred = pipeline.predict(X_test)
accuracy = accuracy_score(Y_test, y_pred)
print("Improved Accuracy:", accuracy)
# Out:
# Improved Accuracy: 0.8536585365853658

# %%
# Check training accuracy
Y_train_pred = pipeline.predict(X_train)
training_accuracy = accuracy_score(Y_train, Y_train_pred)
print("Training Accuracy:", training_accuracy)
# Out:
# Training Accuracy: 1.0

# %%
deploy_data = (0.0629, 0.1065, 0.1526, 0.1229, 0.1437, 0.1190, 0.0884, 0.0907, 0.2107, 0.3597, 0.5466, 0.5205, 0.5127, 0.5395, 0.6558, 0.8705, 0.9786, 0.9335, 0.7917, 0.7383, 0.6908, 0.3850, 0.0671, 0.0502, 0.2717, 0.2839, 0.2234, 0.1911, 0.0408, 0.2531, 0.1979, 0.1891, 0.2433, 0.1956, 0.2667, 0.1340, 0.1073, 0.2023, 0.1794, 0.0227, 0.1313, 0.1775, 0.1549, 0.1626, 0.0708, 0.0129, 0.0795, 0.0762, 0.0117, 0.0061, 0.0257, 0.0089, 0.0262, 0.0108, 0.0138, 0.0187, 0.0230, 0.0057, 0.0113, 0.0131)

# %%
deploy_npdata = np.asarray(deploy_data)
deploy_reshape_data = deploy_npdata.reshape(1,-1)

# %%
prediction = model.predict(deploy_reshape_data)
if (prediction == "R"):
  print("Rock")
elif (prediction == "M"):
  print("Mine")
else:
  print("Neither")
# Out:
# Mine
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
